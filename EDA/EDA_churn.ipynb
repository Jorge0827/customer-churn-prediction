# %% [markdown]
# Columnas del CSV y su significado
#
# customerID
# Traducción: ID del cliente
# Significado: Identificador único de cada cliente en la compañía.
#
# gender
# Traducción: género
# Significado: Sexo de la persona titular de la cuenta (por ejemplo, Male/Female).
#
# SeniorCitizen
# Traducción: ciudadano senior / adulto mayor
# Significado: Indica si el cliente es adulto mayor (normalmente 1 = sí, 0 = no).
#
# Partner
# Traducción: tiene pareja
# Significado: Indica si el cliente declara tener pareja (por ejemplo, Married/Yes/No).
#
# Dependents
# Traducción: dependientes
# Significado: Indica si el cliente tiene personas a su cargo (hijos, familiares dependientes).
#
# tenure
# Traducción: antigüedad (meses)
# Significado: Número de meses que el cliente lleva con el servicio.
#
# PhoneService
# Traducción: servicio telefónico
# Significado: Indica si el cliente tiene contratado servicio de teléfono fijo.
#
# MultipleLines
# Traducción: múltiples líneas telefónicas
# Significado: Indica si el cliente tiene más de una línea de teléfono (por ejemplo, línea adicional).
#
# InternetService
# Traducción: tipo de servicio de internet
# Significado: Tipo de conexión a internet contratada (por ejemplo, DSL, fibra, sin internet).
#
# OnlineSecurity
# Traducción: seguridad en línea
# Significado: Indica si el cliente tiene servicios adicionales de seguridad en internet (antivirus, firewall, etc.).
#
# OnlineBackup
# Traducción: copia de seguridad en línea
# Significado: Indica si el cliente tiene contratado un servicio de respaldo de datos en la nube.
#
# DeviceProtection
# Traducción: protección de dispositivos
# Significado: Servicios de protección para equipos/dispositivos (seguros, soporte extra, etc.).
#
# TechSupport
# Traducción: soporte técnico
# Significado: Indica si el cliente tiene servicio de soporte técnico adicional (por ejemplo, asistencia remota).
#
# StreamingTV
# Traducción: streaming de TV
# Significado: Indica si el cliente tiene contratado servicio de televisión por streaming.
#
# StreamingMovies
# Traducción: streaming de películas
# Significado: Indica si el cliente tiene contratado servicio de películas por streaming.
#
# Contract
# Traducción: tipo de contrato
# Significado: Modalidad del contrato del cliente (mensual, 1 año, 2 años, etc.).
#
# PaperlessBilling
# Traducción: facturación electrónica (sin papel)
# Significado: Indica si el cliente recibe la factura solo en formato digital (correo, web) y no en papel.
#
# PaymentMethod
# Traducción: método de pago
# Significado: Forma en que el cliente paga (tarjeta de crédito, domiciliación bancaria, cheque, etc.).
#
# MonthlyCharges
# Traducción: cargos mensuales
# Significado: Importe que el cliente paga cada mes por todos los servicios contratados.
#
# TotalCharges
# Traducción: cargos totales acumulados
# Significado: Monto total que el cliente ha pagado desde que empezó el servicio (acumulado histórico).
#
# Churn
# Traducción: baja del cliente / abandono
# Significado: Variable objetivo; indica si el cliente se dio de baja de la compañía (Yes = se fue, No = sigue siendo cliente).

# %% [markdown]
# Reto 1 — Define el problema como profesional
#
# Respóndeme esto por escrito (como si fuera un informe):
# 1️⃣ ¿Qué es churn?
# Churn es la tasa porcentual que indica cuantos cliente abandonan
# un servicio o productos durante un periodo por diferentes factores.
#
#
# 2️⃣ ¿Por qué es grave para una empresa?
# Piensa en:
# Pues ya sabiendo lo que es churn pues es muy importantes para las empresas saber los datos de esa tasa, porque pueden tener
# buenos ingresos, pero al cliente abandonar los servicios pues ya van a haber menos ingresos, entonces si hay muchos clientes
# que abandonan pues ellos mismos harán que las malas reseñas o experiencias hayan menos clientes.
#
# Costos de adquisición
#
# Ingresos recurrentes
#
# Valor del cliente (LTV)
#
# 3️⃣ ¿Qué tipo de problema es?
#
# ¿Clasificación o regresión?
# ¿Supervisado o no supervisado?
#
# Churn es un porblema de clasificación binaria ya que solo hay dos opciones se va o se queda y
# es supervisado porque se le cargaaran datos para poder qeu el modleo entrene y haga predicción
# de los proximos clientes si se quedraán o no.
#
# Justifica.
#
# 4️⃣ ¿Qué tipo de variable será “Churn”?
#
# Numérica continua
#
# 5️⃣ ¿Qué es peor para la empresa?
#
# falso negativo, porque creer que estamos reteniendo el cliente y se va será más perdida para la empresa.
# El cliente que creemos que es fiel nos deja un gran vacío al irse y perdidas economicas.
#
#
# 🏗 Reto 2 — Métrica correcta
#
# Si el dataset está desbalanceado (por ejemplo 80% no churn, 20% churn):
#
# ¿Accuracy es buena métrica?
# la métrica que mide el porcentaje total de predicciones correctas (positivas y negativas) realizadas por un modelo de clasificación sobre el total de casos.
#
# Si no, ¿cuáles serían mejores y por qué?
# En churn normalmente son mejores métricas como:
#
# Recall (Sensibilidad) → Qué tantos clientes que realmente se iban logré detectar.
#
# Precision → Qué tan confiables son mis predicciones de riesgo.
# De todos los clientes que el modelo dijo:
# “este se va”
# ¿Cuántos realmente se iban?
#
# F1-score → Balance entre precision y recall.
#
# ROC-AUC → Capacidad general del modelo para separar clases.
# ROC-AUC mide la capacidad del modelo para distinguir entre las clases, evaluando qué tan bien separa los clientes que hacen churn de los que no.
#
# 🧠 Reto 3 — Hipótesis iniciales
#
# Sin ver los datos todavía, plantea 5 hipótesis:
#
# Hipótesis 1:
# Los clientes con contrato mensual presentan mayor tasa de churn que los clientes con contrato anual, debido a menor compromiso contractual.
#
# Hipótesis 2:
# Los clientes con menor antigüedad (tenure < 12 meses) tienen mayor probabilidad de churn, ya que aún no han desarrollado fidelidad.
#
# Hipótesis 3:
# Clientes con cargos mensuales más altos presentan mayor probabilidad de churn debido a sensibilidad al precio.
#
# Hipótesis 4:
# Clientes sin servicios adicionales (seguro, soporte premium, etc.) presentan mayor churn al tener menor integración con el ecosistema del servicio.
#
# Hipótesis 5:
# Clientes que usan pago manual presentan mayor churn que los de débito automático, debido a menor automatización y compromiso financiero.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("../data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
#Balance de clases
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df["TotalCharges"].dtypes
# Out:
# dtype('O')

# %%
#Cambiar de objtect a numerico TotalCharges antes del análsiis
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"].replace(" ", np.nan), errors="coerce")

# %%
#Verificar si quedaorn nulos
df["TotalCharges"].isna().sum()
# Out:
# np.int64(11)

# %%
#ver filas antes de rellenar
df[df["TotalCharges"].isna()][["tenure", "MonthlyCharges", "TotalCharges", "Churn"]]
# Out:
#       tenure  MonthlyCharges  TotalCharges Churn
# 488        0           52.55           NaN    No
# 753        0           20.25           NaN    No
# 936        0           80.85           NaN    No
# 1082       0           25.75           NaN    No
# 1340       0           56.05           NaN    No
# 3331       0           19.85           NaN    No
# 3826       0           25.35           NaN    No
# 4380       0           20.00           NaN    No
# 5218       0           19.70           NaN    No
# 6670       0           73.35           NaN    No
# 6754       0           61.90           NaN    No

# %%
#Analizando que los 11 valores en cero son aquellos que en tenure osea en meses 
# de antiguedad están en cero, Lo mejor es rellenar con 0

df["TotalCharges"] = df["TotalCharges"].fillna(0)

# %%
#Verificar si quedaorn nulos
df["TotalCharges"].isna().sum()
# Out:
# np.int64(0)
